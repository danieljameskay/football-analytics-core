# %%
import pandas as pd
from statsbombpy import sb

# %%
# #call statsbombpy API to get all free competitions
# df = pd.DataFrame(sb.competitions())

# #print a list of free competitions
# df
# Out:
# /Users/dkn293/PycharmProjects/football-analytics-core/.venv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 70              35         75         Europe      UEFA Europa League
# 71              53        315         Europe       UEFA Women's Euro
# 72              53        106         Europe       UEFA Women's Euro
# 73              72        107  International       Women's World Cup
# ...

# %%
matches = sb.matches(competition_id=55, season_id=282)
matches.head()
# Out:
# /Users/dkn293/PycharmProjects/football-analytics-core/.venv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3942819  2024-07-10  22:00:00.000           1           2    available
# 1   3943043  2024-07-14  22:00:00.000           2           1    available
# 2   3942752  2024-07-09  22:00:00.000           2           1    available
# 3   3942382  2024-07-06  22:00:00.000           2           1    available
# 4   3942349  2024-07-05  22:00:00.000           0           0    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2024-07-15T07:54:23.583297  2024-07-15T07:57:36.684453
# 1        available  2024-07-15T15:48:50.315500  2024-07-15T15:52:24.778809
# 2        available  2024-07-10T08:51:07.032303  2024-07-10T13:01:26.597509
# ...

# %%
all_events = []

# Take each value from the match_id column, one at a time...
for match_id in matches['match_id']:
    events = sb.events(match_id=match_id)
    events['match_id'] = match_id
    all_events.append(events)

events_df = pd.concat(all_events, ignore_index=True)
# Out:
# /Users/dkn293/PycharmProjects/football-analytics-core/.venv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events_df.head()
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'block_deflection', 'block_save_block', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot',
#        ...
#        'goalkeeper_success_in_play', 'ball_recovery_offensive',
#        'dribble_no_touch', 'pass_miscommunication', 'player_off_permanent',
#        'goalkeeper_penalty_saved_to_post', 'goalkeeper_shot_saved_off_target',
#        'shot_follows_dribble', 'shot_saved_off_target', 'shot_redirect'],
#       dtype='str', length=114)

# %%
england_netherlands_2024_07_10 = df[df['match_id'] == 3942819]

england_netherlands_2024_07_10
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3942819  2024-07-10  22:00:00.000           1           2    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2024-07-15T07:54:23.583297  2024-07-15T07:57:36.684453
#
#    match_week  ...  home_manager_country_name away_manager_id  \
# 0           6  ...                Netherlands             277
#
#   away_manager_name away_manager_nickname  away_manager_dob  \
# 0  Gareth Southgate                   NaN        1970-09-03
#
#   away_manager_country_id  away_manager_country_name data_version  \
# 0                      68                    England        1.1.0
#
#   shot_fidelity_version xy_fidelity_version
# 0                     2                   2
#
# [1 rows x 55 columns]

# %%
england_netherlands_2024_07_10_events_df = sb.events(match_id=england_netherlands_2024_07_10['match_id'].values[0])
england_netherlands_2024_07_10_events_df
# Out:
# /Users/dkn293/PycharmProjects/football-analytics-core/.venv/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      50_50 bad_behaviour_card ball_receipt_outcome block_deflection  \
# 0      NaN                NaN                  NaN              NaN
# 1      NaN                NaN                  NaN              NaN
# 2      NaN                NaN                  NaN              NaN
# 3      NaN                NaN                  NaN              NaN
# 4      NaN                NaN                  NaN              NaN
# ...    ...                ...                  ...              ...
# 3480   NaN                NaN                  NaN              NaN
# 3481   NaN                NaN                  NaN              NaN
# 3482   NaN        Yellow Card                  NaN              NaN
# 3483   NaN        Yellow Card                  NaN              NaN
# ...

# %%
england_netherlands_2024_07_10_events_df.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'block_deflection', 'block_save_block', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_right_foot', 'counterpress',
#        'dribble_outcome', 'duel_outcome', 'duel_type', 'duration',
#        'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_penalty', 'foul_won_advantage', 'foul_won_defensive',
#        'foul_won_penalty', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_punched_out',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'injury_stoppage_in_chain', 'interception_outcome', 'location',
#        'match_id', 'minute', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
# ...

# %%
import math


england_netherlands_2024_07_10_bad_df = england_netherlands_2024_07_10_events_df['bad_behaviour_card'].values

filtered = [x for x in england_netherlands_2024_07_10_bad_df if not (isinstance(x, float) and math.isnan(x))]


filtered
# Out:
# ['Yellow Card', 'Yellow Card', 'Yellow Card']
